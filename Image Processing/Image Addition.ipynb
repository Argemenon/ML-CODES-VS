# %% [markdown]
# # Image Addition

# %% [markdown]
# ### Non -weighted addition

# %% [markdown]
# Let us try to add the following images:
#
# <img src="Images/space.jpg" width='300'>
#
# <img src="Images/city.jpg" width='300'>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a new np array:

array = np.zeros([426,640,3], dtype= np.uint8)

img1 = cv2.imread('Images/city.jpg', -1)
img2 = cv2.imread('Images/space.jpg', -1)

h,w,c = img1.shape

print(h, w)

# img1_max = np.max(img1)
# img2_max = np.max(img2)

# print(img1_max, img2_max)
# Out:
# 426 640

# %%
# Additing the Images

for i in range(0,h):
    for j in range(0,w):
        array[i,j] = (0.5)*img1[i,j] + (0.5)*img2[i,j]

print(np.max(array))

m = np.max(array)

#Fixing elements so that maximum pixel value is 255

for i in range(0,h):
    for j in range(0,w):
        array[i,j] = array[i,j] + (255-m, 255-m, 255-m)
# Out:
# 238

# %%
print('The maximum value in the array is: ',np.max(array))

plt.imshow(array)

plt.show()
# Out:
# The maximum value in the array is:  255

# %% [markdown]
# # OpenCV

# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# ## Images

# %% [markdown]
# I would like to read the following image located at _/home/argemenon/ML Programs/ML CODES VS/Image Processing/dawn.jpg_
#
# <img src="/home/argemenon/ML Programs/ML CODES VS/Image Processing/dawn.jpg" width=300>

# %%
img= cv2.imread("dawn.jpg",-1)

plt.imshow(img) #OpenCV reads image in BRG format, we have it in RGB format

# %%
rgb_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  #Converting from BRG to RGB

plt.imshow(rgb_img)

# %%
img=cv2.imread("dawn.jpg",1)

bw_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(bw_img)

# %%
img.shape
# Out:
# (1346, 1080, 3)

# %%
img.size
# Out:
# 4361040

# %% [markdown]
# ## Basic Operations with Images

# %% [markdown]
# ### Accessing Particular Colours

# %% [markdown]
# Let us try to break down the components of the following image:
#
# <img src="/home/argemenon/ML Programs/ML CODES VS/Image Processing/rbg.jpg" width=300>

# %%
img2 =  cv2.imread("rbg.jpg",-1)

# %%
img2_blue = img2[:,:,0]
img2_green = img2[:,:,1]
img2_red= img2[:,:,2]

plt.subplot(2,2,1)
plt.imshow(img2)
plt.title("BGR")

plt.subplot(2,2,2)
plt.imshow(img2_blue)
plt.title("B")

plt.subplot(2,2,3)
plt.imshow(img2_green)
plt.title("G")

plt.subplot(2,2,4)
plt.imshow(img2_red)
plt.title("R")
# Out:
# Text(0.5, 1.0, 'R')

# %% [markdown]
# ### Looking at a region of an Image

# %% [markdown]
# Let us see how we can access a particular area of the following image
#
# <img src="/home/argemenon/ML Programs/ML CODES VS/Image Processing/rbg.jpg" width=300>

# %%
img2_region = img2[0:1100,500:1500]  #This helps us look at a region of interest

plt.imshow(img2_region)

# %% [markdown]
# ### Rescaling an Image

# %%
def rescaleFrame(frame, scale=0.75):
    width = int(frame.shape[1]*scale)
    height= int(frame.shape[0]*scale)
    dimensions = (width, height)

    return cv2.resize(frame, dimensions, interpolation=cv2.INTER_AREA)

# %%
cv2.__version__
# Out:
# '4.10.0'

# %%
resized_img= rescaleFrame(img,0.50)
plt.imshow(resized_img)                #Notice the axis values in the resulting plot

# %% [markdown]
# ### Adding two Images
